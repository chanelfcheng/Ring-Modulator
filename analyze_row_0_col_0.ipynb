# %%
import os
import glob
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
import seaborn as sns
sns.set_theme('notebook')
import matplotlib as mpl
import progressbar
import pickle
from scipy.signal import find_peaks, peak_prominences, peak_widths
from datetime import datetime
import warnings

warnings.simplefilter('ignore')
# %run -i helper_functions.py

# %%
data_dir = os.getcwd() + '/Full_Data/'
data = []
row_num = 0
col_num = 0

get_datafiles(data_dir, data, row_num, col_num)

# %%
# plot_VW(data[7], fit_order=8, ideal_peak_wl = 1550, fsr=7, zoom_span=0.75, index=0)

# %%
peak = []
res = []

# extract peak 1
peak.append(extract_peaks(data[0], zoom_span=0.75, ideal_peak_wl=1480))
peak.append(extract_peaks(data[1], prominence=1, zoom_span=0.75, ideal_peak_wl=1475))
peak.append(extract_peaks(data[2], prominence=1, zoom_span=0.75, ideal_peak_wl=1475))
peak.append(extract_peaks(data[3], prominence=1, zoom_span=0.75, ideal_peak_wl=1475))
peak.append(extract_peaks(data[4], prominence=1, zoom_span=0.75, ideal_peak_wl=1475))
peak.append(extract_peaks(data[5], prominence=1, zoom_span=0.75, ideal_peak_wl=1475))

# extract peak 2
peak.append(extract_peaks(data[0], prominence=1, fsr=7, zoom_span=0.5, ideal_peak_wl=1515))
peak.append(extract_peaks(data[1], prominence=1, fsr=7, zoom_span=0.5, ideal_peak_wl=1515))
peak.append(extract_peaks(data[2], prominence=2, fsr=7, zoom_span=0.4, ideal_peak_wl=1510))
peak.append(extract_peaks(data[3], prominence=1, fsr=7, zoom_span=0.5, ideal_peak_wl=1515))
peak.append(extract_peaks(data[4], prominence=1, fsr=7, zoom_span=0.5, ideal_peak_wl=1515))
peak.append(extract_peaks(data[5], prominence=1, fsr=7, zoom_span=0.5, ideal_peak_wl=1515))

# extract peak 3
peak.append(extract_peaks(data[0], zoom_span=0.6, ideal_peak_wl=1550))
peak.append(extract_peaks(data[1], zoom_span=0.75, ideal_peak_wl=1550))
peak.append(extract_peaks(data[2], zoom_span=0.75, ideal_peak_wl=1550))
peak.append(extract_peaks(data[3], zoom_span=0.75, ideal_peak_wl=1550))
peak.append(extract_peaks(data[4], zoom_span=0.75, ideal_peak_wl=1550))
peak.append(extract_peaks(data[5], zoom_span=0.75, ideal_peak_wl=1550))

# extract peak 4
peak.append(extract_peaks(data[0], zoom_span=0.5, ideal_peak_wl=1590, exclude=True))
peak.append(extract_peaks(data[1], zoom_span=0.5, ideal_peak_wl=1590, exclude=True))
peak.append(extract_peaks(data[2], zoom_span=0.5, ideal_peak_wl=1590, exclude=True))
peak.append(extract_peaks(data[3], zoom_span=0.5, ideal_peak_wl=1590, exclude=True))
peak.append(extract_peaks(data[4], zoom_span=0.5, ideal_peak_wl=1590, exclude=True))
peak.append(extract_peaks(data[5], zoom_span=0.4, fsr=1, ideal_peak_wl=1590, exclude=True))

peak = np.array(peak)

# determine average resonances and scale to 0
for i in range(0, len(peak), 6):
    resonances = []
    for j in range(6):
        if (peak[i+j,0][0] != 0):
            resonances.append([peak[i+j,0]])
    res.append( int( np.nan_to_num( np.average(resonances) ) ) )

for i in range(len(peak)):
    peak[i,0] = peak[i,0] - min(peak[i,0])

# for i in range(0, len(peak), 1):
#     resonances = []
#     for j in range(1):
#         if (peak[i+j,0][0] != 0):
#             resonances.append([peak[i+j,0]])
#     res.append( int( np.nan_to_num( np.average(resonances) ) ) )

# for i in range(len(peak)):
#     peak[i,0] = peak[i,0] - min(peak[i,0])

# %%
peak0 = []
res0 = []

peak0.append(extract_peaks(data[6], zoom_span=0.75, ideal_peak_wl=1480))
peak0.append(extract_peaks(data[7], zoom_span=0.75, ideal_peak_wl=1480))
peak0.append(extract_peaks(data[8], zoom_span=0.75, ideal_peak_wl=1480))

peak0.append(extract_peaks(data[6], prominence=1, fsr=7, zoom_span=0.3, ideal_peak_wl=1515))
peak0.append(extract_peaks(data[7], prominence=1, fsr=7, zoom_span=0.3, ideal_peak_wl=1515))
peak0.append(extract_peaks(data[8], prominence=1, fsr=7, zoom_span=0.3, ideal_peak_wl=1515))

peak0.append(extract_peaks(data[6], zoom_span=0.6, ideal_peak_wl=1550))
peak0.append(extract_peaks(data[8], zoom_span=0.6, ideal_peak_wl=1550))
peak0.append(extract_peaks(data[7], zoom_span=0.6, ideal_peak_wl=1550))

peak0.append(extract_peaks(data[6], zoom_span=0.5, ideal_peak_wl=1590, exclude=True))
peak0.append(extract_peaks(data[7], zoom_span=0.5, ideal_peak_wl=1590, exclude=True))
peak0.append(extract_peaks(data[8], zoom_span=0.5, ideal_peak_wl=1590, exclude=True))

peak0 = np.array(peak0)

# determine average resonances and scale to 0
for i in range(0, len(peak0), 1):
    resonances = []
    for j in range(1):
        if (peak0[i+j,0][0] != 0):
            resonances.append([peak0[i+j,0]])
    res0.append( int( np.nan_to_num( np.average(resonances) ) ) )

for i in range(len(peak0)):
    peak0[i,0] = peak0[i,0] - min(peak0[i,0])

# %%
plot_res(data, peak, res, row_num, col_num, peak0=peak0)

# %%
# plot_resonances(data, peak, res, row_num, col_num)

# %%
# plot_average_resonances(data, peak, res, row_num, col_num)
