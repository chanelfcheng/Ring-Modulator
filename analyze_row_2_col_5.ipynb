# %%
import os
import glob
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
import seaborn as sns
sns.set_theme('notebook')
import matplotlib as mpl
import progressbar
import pickle
from scipy.signal import find_peaks, peak_prominences, peak_widths
from datetime import datetime
import warnings

warnings.simplefilter('ignore')
# %run -i helper_functions.py

# %%
data_dir = os.getcwd() + '/Full_Data/'
data = []
row_num = 2
col_num = 5

get_datafiles(data_dir, data, row_num, col_num)

# %%
plot_VW(data[6], index=0, prominence=2, fsr=2, ideal_peak_wl = 1465, zoom_span=0.5)

# %%
peak = []
res = []

# extract peak 1
peak.append(extract_peaks(data[0], zoom_span=0.5, prominence=0.5, ideal_peak_wl=1465))
peak.append(extract_peaks(data[1], zoom_span=0.5, fsr=1, prominence=0.5, ideal_peak_wl=1467))
peak.append(extract_peaks(data[2], zoom_span=0.2, fsr=1, prominence=0.5, ideal_peak_wl=1465))
peak.append(extract_peaks(data[3], zoom_span=0.5, prominence=0.5, ideal_peak_wl=1468))
peak.append(extract_peaks(data[4], zoom_span=0.5, prominence=0.5, ideal_peak_wl=1465))
peak.append(extract_peaks(data[5], zoom_span=0.5, prominence=0.5, ideal_peak_wl=1465))

# extract peak 2
peak.append(extract_peaks(data[0], prominence=0.5, fsr=1, zoom_span=0.4, ideal_peak_wl=1502))
peak.append(extract_peaks(data[1], prominence=0.5, zoom_span=0.5, ideal_peak_wl=1500))
peak.append(extract_peaks(data[2], prominence=0.2, fsr=15, zoom_span=0.4, ideal_peak_wl=1500, exclude=True))
peak.append(extract_peaks(data[3], prominence=0.5, fsr=1, zoom_span=0.25, ideal_peak_wl=1503, exclude=True))
peak.append(extract_peaks(data[4], prominence=0.5, zoom_span=0.5, ideal_peak_wl=1500))
peak.append(extract_peaks(data[5], prominence=0.5, zoom_span=0.5, ideal_peak_wl=1500))

# extract peak 3
peak.append(extract_peaks(data[0], prominence=0.5, fsr=2, zoom_span=0.75, ideal_peak_wl=1540))
peak.append(extract_peaks(data[1], prominence=0.5, fsr=2, zoom_span=0.75, ideal_peak_wl=1540))
peak.append(extract_peaks(data[2], prominence=2, fsr=2, zoom_span=0.75, ideal_peak_wl=1537))
peak.append(extract_peaks(data[3], prominence=2, fsr=2, zoom_span=0.2, ideal_peak_wl=1539, exclude=True))
peak.append(extract_peaks(data[4], prominence=2, fsr=2, zoom_span=0.4, ideal_peak_wl=1541))
peak.append(extract_peaks(data[5], prominence=0.5, fsr=2, zoom_span=0.75, ideal_peak_wl=1539.5))

# extract peak 4
peak.append(extract_peaks(data[0], zoom_span=0.5, ideal_peak_wl=1590, exclude=True))
peak.append(extract_peaks(data[1], zoom_span=0.5, ideal_peak_wl=1590, exclude=True))
peak.append(extract_peaks(data[2], zoom_span=0.5, ideal_peak_wl=1590, exclude=True))
peak.append(extract_peaks(data[3], zoom_span=0.6, ideal_peak_wl=1590, exclude=True))
peak.append(extract_peaks(data[4], zoom_span=0.5, ideal_peak_wl=1590, exclude=True))
peak.append(extract_peaks(data[5], zoom_span=0.45, ideal_peak_wl=1590, exclude=True))

peak = np.array(peak)
print(peak[5,0])

# determine average resonances and scale to 0
for i in range(0, len(peak), 6):
    resonances = []
    for j in range(6):
        if (peak[i+j,0][0] != 0):
            resonances.append([peak[i+j,0]])
    res.append( int( np.nan_to_num( np.average(resonances) ) ) )

for i in range(len(peak)):
    peak[i,0] = peak[i,0] - min(peak[i,0])

# test stuff
# Out:
# [1467.88   1467.87   1467.865  1467.8575 1467.85   1467.84   1467.8275
#  1467.82   1467.805  1467.795  1467.78  ]

# %%
# plot_resonances(data, peak, res, row_num, col_num)

# %%
# plot_average_resonances(data, peak, res, row_num, col_num)

# %%
peak0 = []
res0 = []

peak0.append(extract_peaks(data[6], prominence=0.25, fsr=2, zoom_span=0.5, ideal_peak_wl=1465, exclude=True))
peak0.append(extract_peaks(data[6], prominence=0.25, fsr=2, zoom_span=0.5, ideal_peak_wl=1500, exclude=True))
peak0.append(extract_peaks(data[6], prominence=0.25, fsr=2, zoom_span=0.5, ideal_peak_wl=1540, exclude=True))
peak0.append(extract_peaks(data[6], prominence=0.25, fsr=2, zoom_span=0.5, ideal_peak_wl=1590, exclude=True))

peak0 = np.array(peak0)

# determine average resonances and scale to 0
for i in range(0, len(peak0), 1):
    resonances = []
    for j in range(1):
        if (peak0[i+j,0][0] != 0):
            resonances.append([peak0[i+j,0]])
    res0.append( int( np.nan_to_num( np.average(resonances) ) ) )

for i in range(len(peak0)):
    peak0[i,0] = peak0[i,0] - min(peak0[i,0])

# %%
plot_res(data, peak, res, row_num, col_num, peak0=peak0)
